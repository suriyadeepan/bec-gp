# %% [markdown]
# ## Read Generated data

# %%
import pickle

# %%
data_bec = pickle.load(open('../data/bec2d.data.16.0', 'rb'))

# %%
data_bec['data'][0]
# Out:
# (97.45829534356695,
#  array([[1.08029009e-32, 4.80484604e-32, 1.52785034e-31, ...,
#          2.96563109e-31, 1.04953177e-31, 2.16081188e-32],
#         [4.40046407e-32, 2.23516440e-31, 6.29799567e-31, ...,
#          1.30800557e-30, 4.41878932e-31, 9.37314434e-32],
#         [1.19234698e-31, 5.45008725e-31, 1.67877724e-30, ...,
#          3.26038907e-30, 1.11842807e-30, 2.36641930e-31],
#         ...,
#         [2.34676129e-31, 1.11643354e-30, 3.27970916e-30, ...,
#          1.61498696e-30, 5.68916451e-31, 1.13056758e-31],
#         [9.37506146e-32, 4.46283129e-31, 1.28977286e-30, ...,
#          6.60054397e-31, 2.12374562e-31, 4.67935171e-32],
#         [2.20773090e-32, 1.01690422e-31, 3.07339480e-31, ...,
#          1.42639719e-31, 5.16861344e-32, 9.93796284e-33]]))

# %%
from neuralbec import data

# %%
from time import sleep
for i in range(100, 105):
    #i = 5
    psi = data_bec['data'][i][1]
    x = data_bec['x']
    print(data_bec['data'][i][0])
    data.plot_wave_function(x, psi)
    sleep(3)
# Out:
# 83.99766066828884
# 293.57110914536406
# 138.3540512898212
# 143.0681501033293
# 167.68938470602163
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-c17a267bc56b> in <module>()
#       6     print(data_bec['data'][i][0])
#       7     data.plot_wave_function(x, psi)
# ----> 8     sleep(3)
#
# KeyboardInterrupt:

# %%
type({'a' : 3})
# Out:
# dict
